# %%
import numpy as np
import glob, os
import json

# %% [markdown]
# ## Randomnized Img Dict

# %%
imgs = []

# %%
for file in glob.glob("./img/*.jpg"):
    imgs.append(file)

# %%
seeds = np.random.permutation(len(imgs))
seeds
len(imgs)
# Out:
# 85

# %%
for i in range(0, len(imgs)):
    if seeds[i] == 0:
        tmp = seeds[0]
        seeds[0] = 0
        seeds[i] = tmp
    if seeds[i] == len(imgs)-1:
        tmp = seeds[len(imgs)-1]
        seeds[len(imgs)-1] = len(imgs)-1
        seeds[i] = tmp
    #first break
    if seeds[i] == len(imgs)-7:
        tmp = seeds[12]
        seeds[12] = len(imgs)-7
        seeds[i] = tmp
    #second break
    if seeds[i] == len(imgs)-6:
        tmp = seeds[24]
        seeds[24] = len(imgs)-6
        seeds[i] = tmp
    #third break
    if seeds[i] == len(imgs)-5:
        tmp = seeds[36]
        seeds[36] = len(imgs)-5
        seeds[i] = tmp
    #fourth break
    if seeds[i] == len(imgs)-4:
        tmp = seeds[48]
        seeds[48] = len(imgs)-4
        seeds[i] = tmp
    #fifth break
    if seeds[i] == len(imgs)-3:
        tmp = seeds[60]
        seeds[60] = len(imgs)-3
        seeds[i] = tmp
    #sixth break
    if seeds[i] == len(imgs)-2:
        tmp = seeds[72]
        seeds[72] = len(imgs)-2
        seeds[i] = tmp
seeds
# Out:
# array([ 0, 65, 11, 23, 61,  7, 33, 72, 56, 35, 10,  2, 78,  8, 21, 58, 62,
#        34, 40, 75,  3, 45, 74, 55, 79, 19, 27, 51, 16,  1, 17, 69, 54, 31,
#        49, 46, 80, 60,  4, 22, 63, 18,  5, 43, 73, 24, 15, 12, 81, 20, 38,
#        42, 48, 44, 68, 29, 57, 25, 28, 32, 82, 64, 39, 66, 37, 50, 59, 76,
#        47,  9, 41, 71, 83, 30, 13, 77, 67, 36, 70, 26, 52, 14, 53,  6, 84])

# %%
imgs = np.array(imgs)
imgs
# Out:
# array(['./img/0.jpg', './img/1-1-0-0.jpg', './img/1-1-1-1.jpg',
#        './img/1-1-1-2.jpg', './img/1-1-1-3.jpg', './img/1-1-2-1.jpg',
#        './img/1-1-2-2.jpg', './img/1-1-2-3.jpg', './img/1-2-0-0.jpg',
#        './img/1-2-1-1.jpg', './img/1-2-1-2.jpg', './img/1-2-1-3.jpg',
#        './img/1-2-2-1.jpg', './img/1-2-2-2.jpg', './img/1-2-2-3.jpg',
#        './img/1-3-0-0.jpg', './img/1-3-1-1.jpg', './img/1-3-1-2.jpg',
#        './img/1-3-1-3.jpg', './img/1-3-2-1.jpg', './img/1-3-2-2.jpg',
#        './img/1-3-2-3.jpg', './img/2-1-0-0.jpg', './img/2-1-1-1.jpg',
#        './img/2-1-1-2.jpg', './img/2-1-1-3.jpg', './img/2-1-2-1.jpg',
#        './img/2-1-2-2.jpg', './img/2-1-2-3.jpg', './img/2-2-0-0.jpg',
#        './img/2-2-1-1.jpg', './img/2-2-1-2.jpg', './img/2-2-1-3.jpg',
#        './img/2-2-2-1.jpg', './img/2-2-2-2.jpg', './img/2-2-2-3.jpg',
#        './img/2-3-0-0.jpg', './img/2-3-1-1.jpg', './img/2-3-1-2.jpg',
# ...

# %%
perm_imgs = imgs[seeds]

print (len(perm_imgs))
perm_imgs
# Out:
# 85
# array(['./img/0.jpg', './img/2-3-1-2.jpg', './img/1-1-2-2.jpg',
#        './img/2-2-2-2.jpg', './img/1-3-1-2.jpg', './img/4-1-2-3.jpg',
#        './img/4-1-1-2.jpg', './img/1-3-2-3.jpg', './img/2-1-1-1.jpg',
#        './img/1-2-2-3.jpg', './img/2-3-2-1.jpg', './img/1-1-2-3.jpg',
#        './img/6-1.jpg', './img/2-1-1-2.jpg', './img/4-1-2-2.jpg',
#        './img/1-2-1-1.jpg', './img/2-3-2-3.jpg', './img/3-2-0-0.jpg',
#        './img/3-3-1-1.jpg', './img/4-2-2-2.jpg', './img/4-2-1-3.jpg',
#        './img/2-2-1-3.jpg', './img/2-2-1-2.jpg', './img/1-3-0-0.jpg',
#        './img/6-2.jpg', './img/1-1-1-3.jpg', './img/4-2-2-1.jpg',
#        './img/3-2-2-2.jpg', './img/3-1-1-1.jpg', './img/2-1-2-2.jpg',
#        './img/1-2-2-2.jpg', './img/1-2-0-0.jpg', './img/1-1-1-2.jpg',
#        './img/1-2-2-1.jpg', './img/1-3-2-1.jpg', './img/4-2-2-3.jpg',
#        './img/6-3.jpg', './img/1-1-0-0.jpg', './img/2-3-2-2.jpg',
#        './img/2-3-1-1.jpg', './img/2-3-1-3.jpg', './img/3-2-1-1.jpg',
# ...

# %%
img_dict = {i: perm_imgs[i] for i in range(len(imgs))  }

# %%
#with open("./json/img_json.json", 'w') as outputfile:
#    json.dump(img_dict, outputfile)

# %% [markdown]
# ## try scripting localstorage file

# %% [markdown]
# **To make the following codes work, need to:**
# - Download the right version of geckodriver from "https://github.com/mozilla/geckodriver/releases", upzip and copy the executable file to `usr/local/bin` (this is on mac and ubuntu, could be the same for Windows)
# - Download the right chromedriver and move it into the same folder "https://chromedriver.storage.googleapis.com/index.html?path=2.32/"

# %%
#borrow the work from "https://stackoverflow.com/questions/35508631/access-and-manage-local-storage-from-splinter"
import numpy as np
import glob, os
import json
class LocalStorage:

    def __init__(self, browser):
        self.browser = browser

    def set(self, key, value):
        self.browser.execute_script(\
      "window.localStorage.setItem('{}',{})".format(key, json.dumps(value)))

    def get(self, key):
        return self.browser.evaluate_script(\
      "window.localStorage.getItem('{}')".format(key));

    def get_all(self):
        return self.browser.evaluate_script("""(function(){
      var items = {}, ls = window.localStorage;
      for (var i = 0, k; i < ls.length; i++)
        items[k = ls.key(i)] = ls.getItem(k);
      return items;
      })()""")

    def remove(self, key):
        self.browser.execute_script(\
      "window.localStorage.removeItem('{}');".format(key));

    def clear(self):
        self.browser.execute_script(\
      "window.localStorage.clear();")

# %%
from splinter import Browser
from selenium import webdriver
#driver = webdriver.Chrome()

browser = Browser(driver_name='chrome')
browser.visit("http://localhost:63342/Controlled-Experiments/index.html?_ijt=avcjn26p6p7pjscojqes3hp2vu")
#the url of our website, could be localhost or github io

# get the local storage
storage = LocalStorage(browser)

# get an item
print (storage.get("bgcolor"))

# set an item
storage.set("size", 452)

# remove an item
storage.remove("size")

# get all items
for key, value in storage.get_all().items():
    print (key + ': ' + value)

# delete all items
storage.clear()
# Out:
# None

# %%
for key, value in storage.get_all().items():
    print (key + ': ' + value)
# Out:
# traject76: {"food":"1","num":"1","gender":"1","morph":"1","xy":[{"x":517,"y":504},{"x":506,"y":489},{"x":499,"y":471},{"x":508,"y":428},{"x":573,"y":365},{"x":608,"y":343},{"x":836,"y":240},{"x":1016,"y":173},{"x":1210,"y":102},{"x":1404,"y":31},{"x":1439,"y":3},{"x":1381,"y":0},{"x":1381,"y":0},{"x":1381,"y":17},{"x":1380,"y":25},{"x":1379,"y":26},{"x":1379,"y":27}],"time":1434}
# traject82: {"food":"4","num":"2","gender":"1","morph":"2","xy":[{"x":745,"y":807},{"x":745,"y":806},{"x":745,"y":806},{"x":744,"y":805},{"x":743,"y":804},{"x":742,"y":803},{"x":680,"y":689},{"x":641,"y":613},{"x":571,"y":503},{"x":471,"y":375},{"x":363,"y":250},{"x":271,"y":141},{"x":194,"y":14},{"x":1362,"y":1},{"x":1362,"y":1},{"x":1365,"y":12},{"x":1366,"y":16},{"x":1366,"y":16},{"x":1366,"y":17},{"x":1366,"y":19},{"x":1366,"y":20},{"x":1366,"y":25}],"time":1186}
# ...

# %%
import pickle

with open("./result/tanvi-result.txt", "wb") as outputfile:
    pickle.dump(storage.get_all() ,outputfile)

# %%
with open("./result/tanvi-result.txt", "rb") as inputfile:
    testResult = pickle.load(inputfile)

# %%
import csv
with open('./result/tanvi-result.csv', 'w') as f: 
    w = csv.DictWriter(f, testResult.keys())
    w.writeheader()
    w.writerow(testResult)

# %%
import matplotlib.pyplot as plt
for key, value in testResult.items():
    #print (key + ': ' + value)
    all_dict = json.loads(value)
    xy_dict = all_dict['xy']
    xs = []
    ys = []
    for i in xy_dict:
        xs.append(i['x'])
        ys.append(900-i['y']) 
    plt.xlim(xmax=1500,xmin=0)
    plt.ylim(ymax=1000,ymin=0)
    plt.plot(xs, ys,'ro')
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.xlim(xmax=1000,xmin=0)
plt.ylim(ymax=1000,ymin=0)
plt.plot(xs, ys,'ro')
plt.show()

# %%
with open("./result/micheal-result.txt", "rb") as inputfile:
    testResult = pickle.load(inputfile)
import matplotlib.pyplot as plt
for key, value in testResult.items():
    #print (key + ': ' + value)
    all_dict = json.loads(value)
    xy_dict = all_dict['xy']
    xs = []
    ys = []
    for i in xy_dict:
        xs.append(i['x'])
        ys.append(900-i['y']) 
    plt.xlim(xmax=1500,xmin=0)
    plt.ylim(ymax=1000,ymin=0)
    plt.plot(xs, ys,'ro')
plt.show()

# %%
with open("./result/eric-result.txt", "rb") as inputfile:
    testResult = pickle.load(inputfile)
import matplotlib.pyplot as plt
for key, value in testResult.items():
    #print (key + ': ' + value)
    all_dict = json.loads(value)
    xy_dict = all_dict['xy']
    xs = []
    ys = []
    for i in xy_dict:
        xs.append(i['x'])
        ys.append(900-i['y']) 
    plt.xlim(xmax=1500,xmin=0)
    plt.ylim(ymax=1000,ymin=0)
    plt.plot(xs, ys,'ro')
plt.show()

# %%
with open("./result/emma-result.txt", "rb") as inputfile:
    testResult = pickle.load(inputfile)
import matplotlib.pyplot as plt
for key, value in testResult.items():
    #print (key + ': ' + value)
    all_dict = json.loads(value)
    xy_dict = all_dict['xy']
    xs = []
    ys = []
    for i in xy_dict:
        xs.append(i['x'])
        ys.append(900-i['y']) 
    plt.xlim(xmax=1500,xmin=0)
    plt.ylim(ymax=1000,ymin=0)
    plt.plot(xs, ys,'ro')
plt.show()

# %%
import glob, os
filelist = []
for file in glob.glob("./result/*.txt"):
    filelist.append(file)
filelist
# Out:
# ['./result/alex-result.txt',
#  './result/eric-result.txt',
#  './result/margo-result.txt',
#  './result/dan-result.txt',
#  './result/mark-result.txt',
#  './result/micheal-result.txt',
#  './result/jackson-result.txt',
#  './result/david-result.txt',
#  './result/si-result.txt',
#  './result/rob-result.txt',
#  './result/hao-result.txt',
#  './result/anjali-result.txt',
#  './result/emma-result.txt',
#  './result/yaniv-result.txt']

# %%
import pickle
for file in filelist:
    with open(file, "rb") as inputfile:
        testResult = pickle.load(inputfile)

# %%
# get one dict
file = filelist[2]
with open(file, "rb") as inputfile:
    testResult = pickle.load(inputfile)
testResult
sorted(testResult)
# Out:
# ['traject10',
#  'traject11',
#  'traject12',
#  'traject14',
#  'traject15',
#  'traject16',
#  'traject17',
#  'traject18',
#  'traject19',
#  'traject2',
#  'traject20',
#  'traject21',
#  'traject22',
#  'traject23',
#  'traject24',
#  'traject26',
#  'traject27',
#  'traject28',
#  'traject29',
#  'traject3',
#  'traject30',
#  'traject31',
#  'traject32',
#  'traject33',
#  'traject34',
#  'traject35',
#  'traject36',
#  'traject38',
#  'traject39',
#  'traject4',
#  'traject40',
#  'traject41',
#  'traject42',
#  'traject43',
#  'traject44',
#  'traject45',
#  'traject46',
#  'traject47',
#  'traject48',
#  'traject5',
#  'traject50',
#  'traject51',
#  'traject52',
#  'traject53',
#  'traject54',
#  'traject55',
#  'traject56',
#  'traject57',
#  'traject58',
#  'traject59',
#  'traject6',
#  'traject60',
#  'traject62',
#  'traject63',
#  'traject64',
#  'traject65',
#  'traject66',
#  'traject67',
#  'traject68',
#  'traject69',
#  'traject7',
#  'traject70',
# ...

# %%
# sort the dict
testlist = {}
for key in sorted(testResult):
    testlist[key] = testResult[key]
testlist
# Out:
# {'traject10': '{"food":"1","num":"2","gender":"2","morph":"3","xy":[{"x":739,"y":797},{"x":739,"y":795},{"x":736,"y":773},{"x":730,"y":738},{"x":714,"y":685},{"x":688,"y":629},{"x":651,"y":568},{"x":578,"y":462},{"x":526,"y":395},{"x":481,"y":332},{"x":431,"y":268},{"x":380,"y":227},{"x":340,"y":200},{"x":305,"y":172},{"x":260,"y":133},{"x":236,"y":111},{"x":219,"y":95},{"x":209,"y":85},{"x":198,"y":75},{"x":191,"y":68},{"x":186,"y":63},{"x":185,"y":62},{"x":185,"y":62},{"x":185,"y":62},{"x":185,"y":63},{"x":184,"y":63},{"x":184,"y":63},{"x":183,"y":63},{"x":182,"y":63},{"x":179,"y":63},{"x":172,"y":61},{"x":148,"y":53},{"x":132,"y":47},{"x":120,"y":41},{"x":112,"y":38},{"x":105,"y":36},{"x":101,"y":35},{"x":99,"y":34},{"x":98,"y":33},{"x":97,"y":33},{"x":97,"y":33},{"x":97,"y":33},{"x":96,"y":33},{"x":94,"y":33},{"x":94,"y":32}],"time":2134}',
# ...

# %%
#for key, value in testlist.items():
# sort the dict
dis_list = []
import numpy.linalg
import math

def lineMagnitude (x1, y1, x2, y2):
    lineMagnitude = math.sqrt(math.pow((x2 - x1), 2)+ math.pow((y2 - y1), 2))
    return lineMagnitude
 
#Calc minimum distance from a point and a line segment (i.e. consecutive vertices in a polyline).
def DistancePointLine (px, py, x1, y1, x2, y2):
    #http://local.wasp.uwa.edu.au/~pbourke/geometry/pointline/source.vba
    LineMag = lineMagnitude(x1, y1, x2, y2)
 
    if LineMag < 0.00000001:
        DistancePointLine = 9999
        return DistancePointLine
 
    u1 = (((px - x1) * (x2 - x1)) + ((py - y1) * (y2 - y1)))
    u = u1 / (LineMag * LineMag)
 
    if (u < 0.00001) or (u > 1):
        #// closest point does not fall within the line segment, take the shorter distance
        #// to an endpoint
        ix = lineMagnitude(px, py, x1, y1)
        iy = lineMagnitude(px, py, x2, y2)
        if ix > iy:
            DistancePointLine = iy
        else:
            DistancePointLine = ix
    else:
        # Intersecting point is on the line, use the formula
        ix = x1 + u * (x2 - x1)
        iy = y1 + u * (y2 - y1)
        DistancePointLine = lineMagnitude(px, py, ix, iy)
 
    return DistancePointLine

for key in sorted(testResult):
    value = testResult[key]
    all_dict = json.loads(value)
    xy_dict = all_dict['xy']
    xs = []
    ys = []
    for i in xy_dict:
        xs.append(i['x'])
        ys.append(i['y']) 
    # got x y list
    startpoint = [xs[0], ys[0]]
    endpoint = [xs[-1], ys[-1]]
    maxdis = 0;
    for i in range(1,len(xs)-2):
        #curpoint = [xs[i],ys[i]]
        #d = numpy.linalg.norm(numpy.cross(sub(endpoint, startpoint), startpoint-curpoint))/numpy.linalg.norm(endpoint-startpoint)
        d = DistancePointLine(xs[i], ys[i], xs[0], ys[0], xs[-1], ys[-1])
        if maxdis <= d:
            maxdis = d
    dis_list.append(maxdis)
dis_list
# Out:
# [340.5426049236887,
#  203.2839348862977,
#  95.8081424428701,
#  99.10733554681792,
#  217.98455403928736,
#  156.39289771965167,
#  178.40311432791614,
#  1017.9161789047953,
#  42.5205832509386,
#  45.45327270945405,
#  183.19340101519117,
#  121.28299085243387,
#  775.6673015588256,
#  207.61686971785238,
#  84.92639011510812,
#  230.59915903043924,
#  206.1185396195764,
#  136.71754028273205,
#  68.59742270523759,
#  148.56601120804334,
#  183.49295821956986,
#  87.6777780744916,
#  117.90472328971349,
#  155.87741343997615,
#  184.11878306231822,
#  134.88458175054203,
#  44.57313893729516,
#  97.07775514827782,
#  106.53388928671453,
#  116.7306011061189,
#  82.79702692275545,
#  149.9387450435235,
#  152.08752173865363,
#  68.47712754213943,
#  106.43586271635819,
#  841.8807826605772,
#  576.8353080090767,
#  144.10733875992346,
#  66.2117814289874,
#  818.980343056415,
#  122.54996126295246,
#  1011.4423663855445,
#  277.29487282185056,
#  185.49587406426465,
# ...

# %%
import csv
with open ('./result/maxdistance.csv', 'a+') as f:
    w = csv.writer(f)
    w.writerows([dis_list])

# %%
import glob, os
filelist = []
for file in glob.glob("./result/*.txt"):
    filelist.append(file)
filelist
# Out:
# ['./result/alex-result.txt',
#  './result/anjali-result.txt',
#  './result/dan-result.txt',
#  './result/david-result.txt',
#  './result/emma-result.txt',
#  './result/eric-result.txt',
#  './result/hao-result.txt',
#  './result/jackson-result.txt',
#  './result/margo-result.txt',
#  './result/mark-result.txt',
#  './result/micheal-result.txt',
#  './result/rob-result.txt',
#  './result/si-result.txt',
#  './result/yaniv-result.txt']

# %%
file = filelist[6]
with open(file, "rb") as inputfile:
    testResult = pickle.load(inputfile)
testlist = {}
for key in sorted(testResult):
    testlist[key] = testResult[key]
congruent = []
incongruent = []
neutral = []
for key, value in testlist.items():
    all_dict = json.loads(value)
    food_idx = int(all_dict['food'])
    num_idx = int(all_dict['num'])
    gender_idx = int(all_dict['gender'])
    morph_idx = int(all_dict['morph'])
    if (food_idx == 1 and gender_idx == 1):
        congruent.append(key)
    elif (food_idx == 2 and num_idx == 1 and gender_idx == 1):
        congruent.append(key)
    elif (food_idx == 2 and gender_idx == 2):
        congruent.append(key)
    elif (food_idx == 3 and num_idx == 1 and gender_idx == 2):
        congruent.append(key)
    elif (food_idx == 3 and gender_idx == 1):
        congruent.append(key)
    elif (food_idx == 4):
        neutral.append(key)
    elif (gender_idx == 0):
        neutral.append(key)
    else:
        incongruent.append(key)
len(congruent)
# Out:
# 33

# %%
####this is final part - maxdis

import matplotlib.pyplot as plt
import json
import numpy.linalg
import math
import csv
import pickle
import numpy as np

def lineMagnitude (x1, y1, x2, y2):
    lineMagnitude = math.sqrt(math.pow((x2 - x1), 2)+ math.pow((y2 - y1), 2))
    return lineMagnitude
 
#Calc minimum distance from a point and a line segment (i.e. consecutive vertices in a polyline).
def DistancePointLine (px, py, x1, y1, x2, y2):
    #http://local.wasp.uwa.edu.au/~pbourke/geometry/pointline/source.vba
    LineMag = lineMagnitude(x1, y1, x2, y2)
 
    if LineMag < 0.00000001:
        DistancePointLine = 9999
        return DistancePointLine
 
    u1 = (((px - x1) * (x2 - x1)) + ((py - y1) * (y2 - y1)))
    u = u1 / (LineMag * LineMag)
 
    if (u < 0.00001) or (u > 1):
        #// closest point does not fall within the line segment, take the shorter distance
        #// to an endpoint
        ix = lineMagnitude(px, py, x1, y1)
        iy = lineMagnitude(px, py, x2, y2)
        if ix > iy:
            DistancePointLine = iy
        else:
            DistancePointLine = ix
    else:
        # Intersecting point is on the line, use the formula
        ix = x1 + u * (x2 - x1)
        iy = y1 + u * (y2 - y1)
        DistancePointLine = lineMagnitude(px, py, ix, iy)
 
    return DistancePointLine

# get one dict
for file in filelist:
    with open(file, "rb") as inputfile:
        testResult = pickle.load(inputfile)
    # # sort the dict
    # testlist = {}
    # for key in sorted(testResult):
    #    testlist[key] = testResult[key]
    # sort the dict
    #for congruent
    mean_maxdis = []
    dis_list = []
    for key in congruent:
        value = testResult[key]
        all_dict = json.loads(value)
        xy_dict = all_dict['xy']
        xs = []
        ys = []
        for i in xy_dict:
            xs.append(i['x'])
            ys.append(i['y']) 
        # got x y list
        startpoint = [xs[0], ys[0]]
        endpoint = [xs[-1], ys[-1]]
        maxdis = 0;
        for i in range(1,len(xs)-2):
            #curpoint = [xs[i],ys[i]]
            #d = numpy.linalg.norm(numpy.cross(sub(endpoint, startpoint), startpoint-curpoint))/numpy.linalg.norm(endpoint-startpoint)
            d = DistancePointLine(xs[i], ys[i], xs[0], ys[0], xs[-1], ys[-1])
            if maxdis <= d:
                maxdis = d
        dis_list.append(maxdis)
    mean_maxdis.append(np.mean(dis_list))
    #for incongruent
    dis_list2 = []
    for key in incongruent:
        value = testResult[key]
        all_dict = json.loads(value)
        xy_dict = all_dict['xy']
        xs = []
        ys = []
        for i in xy_dict:
            xs.append(i['x'])
            ys.append(i['y']) 
        # got x y list
        startpoint = [xs[0], ys[0]]
        endpoint = [xs[-1], ys[-1]]
        maxdis = 0;
        for i in range(1,len(xs)-2):
            #curpoint = [xs[i],ys[i]]
            #d = numpy.linalg.norm(numpy.cross(sub(endpoint, startpoint), startpoint-curpoint))/numpy.linalg.norm(endpoint-startpoint)
            d = DistancePointLine(xs[i], ys[i], xs[0], ys[0], xs[-1], ys[-1])
            if maxdis <= d:
                maxdis = d
        dis_list2.append(maxdis)
    mean_maxdis.append(np.mean(dis_list2))
    #for neutral
    dis_list3 = []
    for key in neutral:
        value = testResult[key]
        all_dict = json.loads(value)
        xy_dict = all_dict['xy']
        xs = []
        ys = []
        for i in xy_dict:
            xs.append(i['x'])
            ys.append(i['y']) 
        # got x y list
        startpoint = [xs[0], ys[0]]
        endpoint = [xs[-1], ys[-1]]
        maxdis = 0;
        for i in range(1,len(xs)-2):
            #curpoint = [xs[i],ys[i]]
            #d = numpy.linalg.norm(numpy.cross(sub(endpoint, startpoint), startpoint-curpoint))/numpy.linalg.norm(endpoint-startpoint)
            d = DistancePointLine(xs[i], ys[i], xs[0], ys[0], xs[-1], ys[-1])
            if maxdis <= d:
                maxdis = d
        dis_list3.append(maxdis)
    mean_maxdis.append(np.mean(dis_list3))
    with open ('./result/maxdis.csv', 'a+') as f:
        w = csv.writer(f)
        w.writerows([mean_maxdis])

# %%
####this is final part - auc

import matplotlib.pyplot as plt
import json
import numpy.linalg
import math
import csv
from sklearn import metrics

def lineMagnitude (x1, y1, x2, y2):
    lineMagnitude = math.sqrt(math.pow((x2 - x1), 2)+ math.pow((y2 - y1), 2))
    return lineMagnitude
 
#Calc minimum distance from a point and a line segment (i.e. consecutive vertices in a polyline).
def DistancePointLine (px, py, x1, y1, x2, y2):
    #http://local.wasp.uwa.edu.au/~pbourke/geometry/pointline/source.vba
    LineMag = lineMagnitude(x1, y1, x2, y2)
 
    if LineMag < 0.00000001:
        DistancePointLine = 9999
        return DistancePointLine
 
    u1 = (((px - x1) * (x2 - x1)) + ((py - y1) * (y2 - y1)))
    u = u1 / (LineMag * LineMag)
 
    if (u < 0.00001) or (u > 1):
        #// closest point does not fall within the line segment, take the shorter distance
        #// to an endpoint
        ix = lineMagnitude(px, py, x1, y1)
        iy = lineMagnitude(px, py, x2, y2)
        if ix > iy:
            DistancePointLine = iy
        else:
            DistancePointLine = ix
    else:
        # Intersecting point is on the line, use the formula
        ix = x1 + u * (x2 - x1)
        iy = y1 + u * (y2 - y1)
        DistancePointLine = lineMagnitude(px, py, ix, iy)
 
    return DistancePointLine

# get one dict
for file in filelist:
#file = filelist[0]
    with open(file, "rb") as inputfile:
        testResult = pickle.load(inputfile)
    # sort the dict
    testlist = {}
    for key in sorted(testResult):
        testlist[key] = testResult[key]
    # sort the dict
    auc_list = []
    for key in sorted(testResult):
        value = testResult[key]
        all_dict = json.loads(value)
        xy_dict = all_dict['xy']
        xs = []
        ys = []
        for i in xy_dict:
            xs.append(i['x'])
            ys.append(i['y']) 
        # got x y list
        startpoint = [xs[0], ys[0]]
        endpoint = [xs[-1], ys[-1]]
        new_xs = []
        new_ys = []
        old_disls = []
        for i in range(1,len(xs)-2):
            # new y 
            new_y = DistancePointLine(xs[i], ys[i], xs[0], ys[0], xs[-1], ys[-1])
            # new x
            old_dis = math.sqrt((xs[i]-xs[0])**2 + (ys[i]-ys[0])**2)
            old_disls.append(old_dis)
            new_x = math.sqrt(old_dis**2 - new_y**2)
            new_xs.append(new_x)
            new_ys.append(new_y)
        res = metrics.auc(new_xs, new_ys, reorder=True) 
        auc_list.append(res)
    with open ('./result/auc.csv', 'a+') as f:
        w = csv.writer(f)
        w.writerows([auc_list])

# %%
####this is final part - time

# get one dict
for file in filelist:
    with open(file, "rb") as inputfile:
        testResult = pickle.load(inputfile)
    mean_maxdis = []
    time_list = []
    mean_times = []
    for key in congruent:
        value = testResult[key]
        all_dict = json.loads(value)
        time_dict = all_dict['time']
        times = time_dict
        time_list.append(times)
    mean_times.append(np.mean(time_list))
    
    #for incongruent
    time_list2 = []
    for key in incongruent:
        value = testResult[key]
        all_dict = json.loads(value)
        time_dict = all_dict['time']
        times = time_dict
        time_list2.append(times)
    mean_times.append(np.mean(time_list2))
    
    #for neutral
    time_list3 = []
    for key in neutral:
        value = testResult[key]
        all_dict = json.loads(value)
        time_dict = all_dict['time']
        times = time_dict
        time_list3.append(times)
    mean_times.append(np.mean(time_list3))
    with open ('./result/times.csv', 'a+') as f:
        w = csv.writer(f)
        w.writerows([mean_times])
